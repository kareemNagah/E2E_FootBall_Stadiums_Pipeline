# %%
import pandas as pd 

df = pd.read_csv('/home/kareemngh/FootBallDataEngineering/data/cleaned_stadiums_data_20250506.csv', sep=',', encoding='utf-8')
df.head()
# Out:
#                       stadiums  capacity         region        country  \
# 0  Rungrado 1st of May Stadium    114000      East Asia    North Korea
# 1             Michigan Stadium    107601  North America  United States
# 2                 Ohio Stadium    102780  North America  United States
# 3     Melbourne Cricket Ground    100024        Oceania      Australia
# 4                     Camp Nou     99354         Europe          Spain
#
#                     city        original_stadium_name  \
# 0              Pyongyang  Rungrado 1st of May Stadium
# 1   Ann Arbor - Michigan             Michigan Stadium
# 2        Columbus - Ohio                 Ohio Stadium
# 3              Melbourne     Melbourne Cricket Ground
# 4  Barcelona - Catalonia                     Camp Nou
#
#                     location        lat         lon
# 0  [39.0496732, 125.7753215]  39.049673  125.775322
# 1  [42.2658749, -83.7486841]  42.265875  -83.748684
# 2  [40.0016458, -83.0197374]  40.001646  -83.019737
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   stadiums  382 non-null    object
#  1   capacity  382 non-null    object
#  2   region    382 non-null    object
#  3   country   382 non-null    object
#  4   city      382 non-null    object
# dtypes: object(5)
# memory usage: 15.1+ KB

# %%
df.dtypes
# Out:
# stadiums    object
# capacity    object
# region      object
# country     object
# city        object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# changing the data type of the capacity column to int 
df['capacity'] = df['capacity'].str.replace(',', '').astype(int)

# %%
df.dtypes
# Out:
# stadiums    object
# capacity     int64
# region      object
# country     object
# city        object
# dtype: object

# %%
df.head()
# Out:
#                       stadiums  capacity         region        country  \
# 0  Rungrado 1st of May Stadium    114000      East Asia    North Korea
# 1             Michigan Stadium    107601  North America  United States
# 2                 Ohio Stadium    102780  North America  United States
# 3     Melbourne Cricket Ground    100024        Oceania      Australia
# 4                     Camp Nou     99354         Europe          Spain
#
#                    city
# 0             Pyongyang
# 1   Ann Arbor, Michigan
# 2        Columbus, Ohio
# 3             Melbourne
# 4  Barcelona, Catalonia

# %%
df['city'] = df['city'].str.replace(', ',' - ')

# %%
df.head()
# Out:
#                       stadiums  capacity         region        country  \
# 0  Rungrado 1st of May Stadium    114000      East Asia    North Korea
# 1             Michigan Stadium    107601  North America  United States
# 2                 Ohio Stadium    102780  North America  United States
# 3     Melbourne Cricket Ground    100024        Oceania      Australia
# 4                     Camp Nou     99354         Europe          Spain
#
#                     city
# 0              Pyongyang
# 1   Ann Arbor - Michigan
# 2        Columbus - Ohio
# 3              Melbourne
# 4  Barcelona - Catalonia

# %%
import json
json.loads(df.to_json(orient='records'))
# Out:
# [{'stadiums': 'Rungrado 1st of May Stadium',
#   'capacity': 114000,
#   'region': 'East Asia',
#   'country': 'North Korea',
#   'city': 'Pyongyang'},
#  {'stadiums': 'Michigan Stadium',
#   'capacity': 107601,
#   'region': 'North America',
#   'country': 'United States',
#   'city': 'Ann Arbor - Michigan'},
#  {'stadiums': 'Ohio Stadium',
#   'capacity': 102780,
#   'region': 'North America',
#   'country': 'United States',
#   'city': 'Columbus - Ohio'},
#  {'stadiums': 'Melbourne Cricket Ground',
#   'capacity': 100024,
#   'region': 'Oceania',
#   'country': 'Australia',
#   'city': 'Melbourne'},
#  {'stadiums': 'Camp Nou',
#   'capacity': 99354,
#   'region': 'Europe',
#   'country': 'Spain',
#   'city': 'Barcelona - Catalonia'},
#  {'stadiums': 'FNB Stadium',
#   'capacity': 94736,
#   'region': 'Africa',
#   'country': 'South Africa',
#   'city': 'Johannesburg'},
#  {'stadiums': 'New Administrative Capital Stadium',
#   'capacity': 93940,
#   'region': 'Africa',
# ...

# %%
cleaned_df = pd.read_csv('/home/kareemngh/FootBallDataEngineering/data/cleaned_stadiums_data_20250506.csv')

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   stadiums               382 non-null    object
#  1   capacity               382 non-null    int64
#  2   region                 382 non-null    object
#  3   country                382 non-null    object
#  4   city                   382 non-null    object
#  5   original_stadium_name  382 non-null    object
#  6   location               382 non-null    object
#  7   lat                    382 non-null    float64
#  8   lon                    382 non-null    float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 27.0+ KB

# %%
cleaned_df.loc[cleaned_df['location'] == 'Location not found'].count()
# Out:
# stadiums                 0
# capacity                 0
# region                   0
# country                  0
# city                     0
# original_stadium_name    0
# location                 0
# lat                      0
# lon                      0
# dtype: int64
